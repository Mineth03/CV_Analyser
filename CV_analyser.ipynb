# %%
# %pip install langchain openai chromadb pdfminer.six
# Out:
# ...
#      ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#      - -------------------------------------- 0.0/1.0 MB 1.3 MB/s eta 0:00:01
#      - -------------------------------------- 0.0/1.0 MB 1.3 MB/s eta 0:00:01
#      - -------------------------------------- 0.0/1.0 MB 1.3 MB/s eta 0:00:01
#      ---- ----------------------------------- 0.1/1.0 MB 654.9 kB/s eta 0:00:02
#      --------- ------------------------------ 0.2/1.0 MB 958.6 kB/s eta 0:00:01
#      ---------- ----------------------------- 0.3/1.0 MB 1.0 MB/s eta 0:00:01
#      ---------- ----------------------------- 0.3/1.0 MB 1.0 MB/s eta 0:00:01
#      --------------- ------------------------ 0.4/1.0 MB 1.0 MB/s eta 0:00:01
#      -------------------- ------------------- 0.5/1.0 MB 1.3 MB/s eta 0:00:01
#      ----------------------------- ---------- 0.8/1.0 MB 1.7 MB/s eta 0:00:01
#      ----------------------------- ---------- 0.8/1.0 MB 1.7 MB/s eta 0:00:01
# ...

# %%
# %pip install -U langchain-community
# Out:
# ...
#      ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#      - -------------------------------------- 0.1/2.5 MB 1.2 MB/s eta 0:00:03
#      --- ------------------------------------ 0.2/2.5 MB 1.5 MB/s eta 0:00:02
#      --- ------------------------------------ 0.2/2.5 MB 1.5 MB/s eta 0:00:02
#      ------ --------------------------------- 0.4/2.5 MB 2.1 MB/s eta 0:00:01
#      -------- ------------------------------- 0.5/2.5 MB 2.1 MB/s eta 0:00:01
#      --------- ------------------------------ 0.6/2.5 MB 2.3 MB/s eta 0:00:01
#      ----------- ---------------------------- 0.8/2.5 MB 2.3 MB/s eta 0:00:01
#      ------------ --------------------------- 0.8/2.5 MB 2.0 MB/s eta 0:00:01
#      ------------- -------------------------- 0.8/2.5 MB 2.0 MB/s eta 0:00:01
#      -------------- ------------------------- 0.9/2.5 MB 2.0 MB/s eta 0:00:01
# ...

# %%
# %pip install transformers accelerate bitsandbytes
# %pip install langchain chromadb pdfminer.six
# Out:
# ...
#      ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#      --------------------------------------- 0.1/10.8 MB 787.7 kB/s eta 0:00:14
#      --------------------------------------- 0.1/10.8 MB 787.7 kB/s eta 0:00:14
#      --------------------------------------- 0.1/10.8 MB 787.7 kB/s eta 0:00:14
#       -------------------------------------- 0.2/10.8 MB 908.0 kB/s eta 0:00:12
#       -------------------------------------- 0.2/10.8 MB 846.9 kB/s eta 0:00:13
#       -------------------------------------- 0.3/10.8 MB 944.1 kB/s eta 0:00:12
#       -------------------------------------- 0.3/10.8 MB 944.1 kB/s eta 0:00:12
#       -------------------------------------- 0.3/10.8 MB 944.1 kB/s eta 0:00:12
#      - -------------------------------------- 0.5/10.8 MB 1.1 MB/s eta 0:00:10
#      -- ------------------------------------- 0.6/10.8 MB 1.2 MB/s eta 0:00:09
# ...

# %%
import os
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
from langchain.document_loaders import PDFMinerLoader, TextLoader
from langchain.schema import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings, HuggingFaceEmbeddings
from langchain.vectorstores import Chroma
from langchain.llms import HuggingFacePipeline, OpenAI
from langchain.chains import RetrievalQA

# %%
os.environ["OPENAI_API_KEY"] = "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"

# %%
# Load CV and Job Description (PDF format)
cv_loader = PDFMinerLoader("CV.pdf")
jd_loader = TextLoader("JD.txt")

cv_docs = cv_loader.load()
jd_docs = jd_loader.load()

# Combine both
all_docs = cv_docs + jd_docs

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)
chunked_docs = splitter.split_documents(all_docs)

# %%
embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# Create vector store from chunked documents
vectorstore = Chroma.from_documents(
    chunked_docs,
    embedding_model,
    persist_directory="./db"  # This allows saving to disk
)

vectorstore.persist()
# Out:
# c:\Users\asus\OneDrive\Desktop\Projects\CV Analyser\.venv\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\asus\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
retriever = vectorstore.as_retriever()

# %%
from huggingface_hub import login
login(token="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")

# %%
model_name = "mistralai/Mistral-7B-Instruct-v0.2"

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",       # Use your GPU if available
    load_in_4bit=True        # Efficient for 8GB GPUs
)

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=512,
    temperature=0.3,
    do_sample=True
)

llm = HuggingFacePipeline(pipeline=pipe)
# Out:
# c:\Users\asus\OneDrive\Desktop\Projects\CV Analyser\.venv\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\asus\.cache\huggingface\hub\models--mistralai--Mistral-7B-Instruct-v0.2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
question = "Does the candidate have experience with AWS and NLP as required in the JD?"

answer = qa_chain.run(question)
print("Answer:", answer)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_13880\1316438144.py:3: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   answer = qa_chain.run(question)
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[25], line 3
#       1 question = "Does the candidate have experience with AWS and NLP as required in the JD?"
# ----> 3 answer = qa_chain.run(question)
#       4 print("Answer:", answer)
#
# File c:\Users\asus\OneDrive\Desktop\Projects\CV Analyser\.venv\lib\site-packages\langchain_core\_api\deprecation.py:189, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     187     warned = True
#     188     emit_warning()
# --> 189 return wrapped(*args, **kwargs)
#
# ...
